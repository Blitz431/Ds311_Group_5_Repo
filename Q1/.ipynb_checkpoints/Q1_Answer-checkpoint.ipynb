# %%
#I am answering the question

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_excel(r"C:\Users\arnie\Coding\Ds311_Group_5_Repo\Q1\fifa_world_cup_cleaned.xlsx", engine='openpyxl',header=None)

df.columns = [
    "date", "home_team", "away_team", "home_region", "away_region",
    "home_rank", "away_rank", "neutral", "importance", "home_score",
    "away_score", "tournament", "city", "venue", "neutral_flag", "extra_col", "result"
]

df.head()
# Out:
#         date home_team     away_team    home_region      away_region  \
# 0 1993-08-08   Bolivia       Uruguay  South America  South America.1
# 1 1993-08-08    Brazil        Mexico  South America    North America
# 2 1993-08-08   Ecuador     Venezuela  South America    South America
# 3 1993-08-08    Guinea  Sierra Leone         Africa           Africa
# 4 1993-08-08  Paraguay     Argentina  South America    South America
#
#    home_rank  away_rank  neutral  importance  home_score  away_score  \
# 0         59         22        0         0.1           3           1
# 1          8         14        0         0.0           1           1
# 2         35         94        0         0.0           5           0
# 3         65         86        0         0.0           1           0
# 4         67          5        0         0.0           1           3
#
#                      tournament       city      venue neutral_flag extra_col  \
# ...

# %%
#home and away stats
home_df = df[["home_team", "away_team", "home_score", "away_score"]].copy()
home_df.columns = ["team", "opponent", "goals_for", "goals_against"]

away_df = df[["away_team", "home_team", "away_score", "home_score"]].copy()
away_df.columns = ["team", "opponent", "goals_for", "goals_against"]

team_stats = pd.concat([home_df, away_df], ignore_index=True)

#summary
team_summary = team_stats.groupby("team").agg(
    matches_played=("goals_for", "count"),
    avg_goals_scored=("goals_for", "mean"),
    avg_goals_conceded=("goals_against", "mean")
).reset_index()

#midfielders 
team_summary["goal_difference"] = team_summary["avg_goals_scored"] - team_summary["avg_goals_conceded"]

top_midfield = team_summary.sort_values(by="goal_difference", ascending=False).head(10)

# %%
top_offense = team_summary.sort_values(by="avg_goals_scored", ascending=False).head(10)
top_offense
# Out:
#                 team  matches_played  avg_goals_scored  avg_goals_conceded  \
# 75           Germany             390          2.243590            1.002564
# 174            Spain             354          2.206215            0.700565
# 27            Brazil             433          2.203233            0.692841
# 135    New Caledonia              65          2.200000            1.169231
# 134      Netherlands             340          2.058824            0.844118
# 11         Australia             307          2.048860            0.947883
# 170  Solomon Islands             113          2.017699            1.849558
# 152         Portugal             336          1.988095            0.797619
# 69              Fiji             109          1.972477            1.339450
# 89           IR Iran             366          1.948087            0.765027
#
#      goal_difference
# 75          1.241026
# 174         1.505650
# 27          1.510393
# 135         1.030769
# 134         1.214706
# ...

# %%
top_defense = team_summary.sort_values(by="avg_goals_conceded").head(10)
top_defense
# Out:
#             team  matches_played  avg_goals_scored  avg_goals_conceded  \
# 27        Brazil             433          2.203233            0.692841
# 174        Spain             354          2.206215            0.700565
# 71        France             370          1.810811            0.718919
# 129      Morocco             323          1.535604            0.743034
# 62       England             334          1.886228            0.751497
# 89       IR Iran             366          1.948087            0.765027
# 152     Portugal             336          1.988095            0.797619
# 95         Italy             351          1.589744            0.806268
# 134  Netherlands             340          2.058824            0.844118
# 163      Senegal             325          1.390769            0.889231
#
#      goal_difference
# 27          1.510393
# 174         1.505650
# 71          1.091892
# 129         0.792570
# 62          1.134731
# 89          1.183060
# 152         1.190476
# ...

# %%
# i want to build some kind of graph but i will try to work on that another time

# %%
# Offensive Teams scoering
plt.figure(figsize=(10,5))
plt.bar(top_offense['team'], top_offense['avg_goals_scored'])
plt.title('Top 10 Offensive Teams (Avg Goals Scored)')
plt.ylabel('Avg Goals Scored')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
top_defense = team_summary.sort_values(by="avg_goals_conceded").head(10)
# Defesnive Teams not letting them score
plt.figure(figsize=(10, 5))
plt.bar(top_defense["team"], top_defense["avg_goals_conceded"])
plt.title("Top 10 Defensive Teams (Avg Goals Conceded)")
plt.ylabel("Avg Goals Conceded")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
#midfielder assits 
top_midfield = team_summary.sort_values(by="goal_difference", ascending=False).head(10)

plt.figure(figsize=(10,5))
plt.bar(top_midfield['team'], top_midfield['goal_difference'])
plt.title('Top 10 Teams by Goal Differential (Midfield Strength Proxy)')
plt.ylabel('Avg Goal Differential')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
world_cup = df[df["tournament"] == "FIFA World Cup"]
#home
home_wc = world_cup[["home_team", "away_team", "home_score", "away_score"]].copy()
home_wc.columns = ["team", "opponent", "goals_for", "goals_against"]
#away
away_wc = world_cup[["away_team", "home_team", "away_score", "home_score"]].copy()
away_wc.columns = ["team", "opponent", "goals_for", "goals_against"]

wc_stats = pd.concat([home_wc, away_wc], ignore_index=True)

wc_stats["win"] = wc_stats["goals_for"] > wc_stats["goals_against"]
wc_stats["loss"] = wc_stats["goals_for"] < wc_stats["goals_against"]

wc_summary = wc_stats.groupby("team").agg(
    matches_played=("goals_for", "count"),
    wins=("win", "sum"),
    losses=("loss", "sum")
).reset_index()

wc_summary = wc_summary.sort_values(by="wins", ascending=False)

print(wc_summary.head(10))
# Out:
#            team  matches_played  wins  losses
# 8        Brazil              43    29       7
# 23      Germany              40    28       8
# 22       France              32    19       5
# 2     Argentina              33    19       8
# 36  Netherlands              29    18       5
# 55        Spain              31    17       6
# 29        Italy              29    14       6
# 5       Belgium              23    13       5
# 15      Croatia              23    11       8
# 21      England              28    11       8

# %% [markdown]
# ### Answer
#
# I looked at their average goals scored, average goals conceded, and goal difference. I decided that the strongest offense is the team that scores the most goals, the strongest defense is the team that gives up the fewest goals, and the strongest midfield is the team with the biggest goal difference. Teams that showed up in the top ten for both offense and defense were overall the best-performing teams. Brazil stood out the most because they had one of the strongest defenses and the third-best offense, showing they are strong in every part of the game. Using these stats gave a good way to measure how strong each team was overall.
